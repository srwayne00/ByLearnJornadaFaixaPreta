# %% [markdown]
# ###### *Jornada Python Faixa Preta, é um curso gratuito oferecido pela ByLearn 4° aula 08-10-2020*

# %%
# School manager => gestão escola

# import math => pacote matematica

# %%
import math

numero = 25

raiz_quadrada = math.sqrt(numero) 
ao_cubo = math.pow(raiz_quadrada, 3)

print('A raiz quadrada do numero indicado é: ',raiz_quadrada, 'e o raiz ao cubo é: ',ao_cubo)
# Out:
# A raiz quadrada do numero indicado é:  5.0 e o raiz ao cubo é:  125.0

# %%
#pip install schoolmanager 
#numpy para vetores e matrizes
#pandas
#pillow para imagens
#tensorflow
#request
#pdfkit para pdfs
#matplotlib para graficos

# %%
# Expressões regulares (RegEx) = são padroes utilizados para selecionar combinações de caracteres em uma string, basicamente um crtl + F

# %%
#importando o modulo do request e json

#import request
#import json

# %%
#import sqlite3 importar um banco de dados
