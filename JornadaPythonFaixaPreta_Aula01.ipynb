# %% [markdown]
# ###### *Jornada Python Faixa Preta, é um curso gratuito oferecido pela ByLearn 1° aula 05-10-2020*

# %% [markdown]
# # Professor Felipe Cabrera (Zarcky)
#
# # Introdução ao Python
# # O que é programação
# # O que um algoritmo
# # Linguagem de programação
# # Algoritmo Vs Codigo
# # O que é compilação
# # Interpretar
# # Compilar Vs Interpretar
# # O que é python, como surgiu
# # Empresas que usam o python
#
#
# ## Apostila da primeira aula na pasta do projeto!!
